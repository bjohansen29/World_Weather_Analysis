# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b9ea3ea438c97c2c6a7878b54ad9f196

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 799

# %%
cities
# Out:
# ['thunder bay',
#  'punta arenas',
#  'hithadhoo',
#  'rikitea',
#  'ust-ishim',
#  'urumqi',
#  'barentsburg',
#  'lebu',
#  'arraial do cabo',
#  'cape town',
#  'airai',
#  'bambous virieux',
#  'ciudad bolivar',
#  'saskylakh',
#  'cayenne',
#  'ushuaia',
#  'new norfolk',
#  'kenora',
#  'langsa',
#  'bethel',
#  'carballo',
#  'mys shmidta',
#  'lanzhou',
#  'saint-philippe',
#  'busselton',
#  'san jeronimo',
#  'moron',
#  'jamestown',
#  'kavieng',
#  'miri',
#  'taolanaro',
#  'broken hill',
#  'atuona',
#  'albany',
#  'port augusta',
#  'kavaratti',
#  'atar',
#  'warrnambool',
#  'liverpool',
#  'talnakh',
#  'port blair',
#  'vardo',
#  'avarua',
#  'labuhan',
#  'port moresby',
#  'inderborskiy',
#  'pringsewu',
#  'rojhan',
#  'east london',
#  'mae hong son',
#  'maragogi',
#  'taldan',
#  'longyearbyen',
#  'victoria',
#  'constitucion',
#  'davila',
#  'mataura',
#  'carnarvon',
#  'bluff',
#  'donja dubica',
#  'la ronge',
#  'bredasdorp',
#  'port elizabeth',
#  'hobart',
#  'katobu',
#  'severo-kurilsk',
#  'mahebourg',
#  'nikolskoye',
#  'grand-santi',
#  'yellowknife',
#  'rocha',
#  'fallon',
#  'cocorit',
#  'marovoay',
#  'sentyabrskiy',
#  'saint-joseph',
#  'yumen',
#  'bolgatanga',
#  'imbituba',
#  'maarianhamina',
#  'caconda',
#  'la orilla',
#  'kamskiye polyany',
#  'hermanus',
#  'tuktoyaktuk',
#  'hokitika',
#  'songea',
#  'vaini',
#  'chokurdakh',
#  'huarmey',
#  'paamiut',
#  'leningradskiy',
#  'changji',
#  'rab',
#  'haukipudas',
#  'baft',
#  'castro',
#  'asyut',
#  'krasnaya zarya',
#  'dongsheng',
#  'fevralsk',
#  'paranagua',
#  'odweyne',
#  'katsiveli',
#  'tuatapere',
#  'tevaitoa',
#  'torbay',
#  'vila velha',
#  'inirida',
#  'hilo',
#  'college',
#  'sochi',
#  'geraldton',
#  'nagorsk',
#  'tasiilaq',
#  'barrow',
#  'kapaa',
#  'bonoua',
#  'hobyo',
#  'volax',
#  'komyshuvakha',
#  'chitral',
#  'tsihombe',
#  'isangel',
#  'vysokogornyy',
#  'illoqqortoormiut',
#  'les cayes',
#  'gandai',
#  'san patricio',
#  'butaritari',
#  'cockburn town',
#  'samusu',
#  'pevek',
#  'barbar',
#  'jiroft',
#  'bressuire',
#  'iqaluit',
#  'georgetown',
#  'anuchino',
#  'kruisfontein',
#  'kirensk',
#  'san quintin',
#  'willowmore',
#  'mukhen',
#  'mareeba',
#  'san cristobal',
#  'sao geraldo do araguaia',
#  'kachug',
#  'khargapur',
#  'chumikan',
#  'camacha',
#  'puerto ayora',
#  'hirosaki',
#  'qaanaaq',
#  'dakar',
#  'thinadhoo',
#  'belushya guba',
#  'canutama',
#  'nome',
#  'inuvik',
#  'ancud',
#  'lata',
#  'dingle',
#  'manta',
#  'eureka',
#  'america dourada',
#  'formosa do rio preto',
#  'khatanga',
#  'marcona',
#  'sur',
#  'asmara',
#  'sinkat',
#  'saint-augustin',
#  'nanortalik',
#  'malabo',
#  'port alfred',
#  'vao',
#  'klaksvik',
#  'saint george',
#  'muros',
#  'thompson',
#  'faanui',
#  'mahon',
#  'grand gaube',
#  'cheuskiny',
#  'amderma',
#  'buon me thuot',
#  'zeya',
#  'ganzhou',
#  'nelson bay',
#  'anadyr',
#  'grindavik',
#  'revelstoke',
#  'atambua',
#  'aksarayskiy',
#  'doctor pedro p. pena',
#  'roseburg',
#  'henties bay',
#  'caetite',
#  'mar del plata',
#  'korla',
#  'raisen',
#  'saint anthony',
#  'sinazongwe',
#  'gazanjyk',
#  'tambopata',
#  'burica',
#  'pisco',
#  'avera',
#  'ketchikan',
#  'tamboril',
#  'trzacka rastela',
#  'rafraf',
#  'grand forks',
#  'zhigansk',
#  'los algarrobos',
#  'lagoa',
#  'bako',
#  'bengkulu',
#  'ayr',
#  'sembakung',
#  'gurskoye',
#  'cherskiy',
#  'mbinga',
#  'lorengau',
#  'novaya bryan',
#  'sychevka',
#  'cabo san lucas',
#  'amancio',
#  'sokolo',
#  'solsvik',
#  'norman wells',
#  'dikson',
#  'bowen',
#  'mercedes',
#  'sumbe',
#  'binzhou',
#  'okato',
#  'zhongshu',
#  'maracas',
#  'kahului',
#  'ginda',
#  'esperance',
#  'ostrovnoy',
#  'tongzi',
#  'chagda',
#  'coihaique',
#  'rio gallegos',
#  'hasaki',
#  'forestville',
#  'mizdah',
#  'zhytomyr',
#  'pangody',
#  'kalmunai',
#  'xichang',
#  'balao',
#  'mwinilunga',
#  'calama',
#  'mount kisco',
#  'shwebo',
#  'lyudinovo',
#  'deyang',
#  'sabang',
#  'upernavik',
#  'polunochnoye',
#  'kununurra',
#  'oranjemund',
#  'borogontsy',
#  'linxia',
#  'sinnamary',
#  'kribi',
#  'saint-pierre',
#  'praia',
#  'paracuru',
#  'bubaque',
#  'lompoc',
#  'ermelo',
#  'waipawa',
#  'leh',
#  'suzu',
#  'coquimbo',
#  'codrington',
#  'alihe',
#  'pangnirtung',
#  'maryville',
#  'ponta do sol',
#  'chernyshevskiy',
#  'kenai',
#  'srednekolymsk',
#  'kaitangata',
#  'chadan',
#  'anchorage',
#  'kikwit',
#  'seoul',
#  'benguela',
#  'pekan',
#  'riachao',
#  'port lincoln',
#  'high level',
#  'emborion',
#  'carahue',
#  'barsovo',
#  'petropavlovsk-kamchatskiy',
#  'muisne',
#  'clyde river',
#  'fernandopolis',
#  'chalmette',
#  'broome',
#  'louisbourg',
#  'komsomolskiy',
#  'southbridge',
#  'sechura',
#  'gizo',
#  'nouadhibou',
#  'longlac',
#  'port said',
#  'mokhsogollokh',
#  'bayanday',
#  'brae',
#  'igunga',
#  'olafsvik',
#  'kholodnyy',
#  'comodoro rivadavia',
#  'wismar',
#  'colombia',
#  'santa comba',
#  'malaryta',
#  'uyuni',
#  'oistins',
#  'ahipara',
#  'lolua',
#  'qaqortoq',
#  'sungai besar',
#  'troitskoye',
#  'nieuw amsterdam',
#  'tiksi',
#  'waingapu',
#  'aklavik',
#  'billings',
#  'lasa',
#  'umm durman',
#  'inta',
#  'yeppoon',
#  'provideniya',
#  'bathsheba',
#  'bandarbeyla',
#  'inongo',
#  'padang',
#  'jining',
#  'khonuu',
#  'binga',
#  'mendi',
#  'botou',
#  'necochea',
#  'asau',
#  'bridlington',
#  'cobija',
#  'evensk',
#  'marion',
#  'ayagoz',
#  'archidona',
#  'fort nelson',
#  'rawson',
#  'teguldet',
#  'one hundred mile house',
#  'bosaso',
#  'vila franca do campo',
#  'linjiang',
#  'punta gorda',
#  'faya',
#  'talcahuano',
#  'shchelyayur',
#  'kamenskoye',
#  'kodiak',
#  'mount isa',
#  'asosa',
#  'dauphin',
#  'guarapari',
#  'mao',
#  'dunmore town',
#  'voiron',
#  'flinders',
#  'talisay',
#  'sile',
#  'nicoya',
#  'artvin',
#  'mitsamiouli',
#  'whitehorse',
#  'sao filipe',
#  'halalo',
#  'tenenkou',
#  'neiafu',
#  'tucurui',
#  'baghdad',
#  'luderitz',
#  'minna',
#  'homer',
#  'yatou',
#  'imatra',
#  'pundaguitan',
#  'souillac',
#  'nikel',
#  'guerrero negro',
#  'jinchang',
#  'chizhou',
#  'egvekinot',
#  'vaitupu',
#  'roald',
#  'saint-georges',
#  'tiberias',
#  'tuban',
#  'ajdabiya',
#  'almaznyy',
#  'namibe',
#  'aflu',
#  'noyabrsk',
#  'palmer',
#  'palabuhanratu',
#  'bikin',
#  'cinisi',
#  'shimoda',
#  'turukhansk',
#  'balsas',
#  'roma',
#  'camocim',
#  'sao joao da barra',
#  'dunedin',
#  'ribeira grande',
#  'attawapiskat',
#  'cidreira',
#  'narsaq',
#  'pavilosta',
#  'te anau',
#  'ruteng',
#  'thessalon',
#  'estevan',
#  'nizhneyansk',
#  'octeville',
#  'honningsvag',
#  'kasungu',
#  'spa',
#  'at-bashi',
#  'oktyabrskoye',
#  'portland',
#  'harper',
#  'adoni',
#  'kasongo-lunda',
#  'road town',
#  'flin flon',
#  'north bend',
#  'presidente medici',
#  'chingirlau',
#  'gat',
#  'vestmannaeyjar',
#  'kalundborg',
#  'playa vicente',
#  'yar-sale',
#  'honiara',
#  'ruatoria',
#  'veraval',
#  'plouzane',
#  'ambon',
#  'hailar',
#  'vejprty',
#  'fairbanks',
#  'nara',
#  'doraha',
#  'valparaiso',
#  'cayeli',
#  'stokmarknes',
#  'bondo',
#  'viana',
#  'hovd',
#  'svirsk',
#  'yaan',
#  'bafq',
#  'suoyarvi',
#  'chandler',
#  'mahibadhoo',
#  'sitka',
#  'luanda',
#  'tambovka',
#  'cananeia',
#  'labytnangi',
#  'monterey',
#  'umzimvubu',
#  'ballina',
#  'horni benesov',
#  'dangriga',
#  'bolungarvik',
#  'wyszkow',
#  'adrar',
#  'olinda',
#  'marystown',
#  'mogadishu',
#  'muroto',
#  'sao miguel do araguaia',
#  'winslow',
#  'manzil salim',
#  'khor',
#  'puerto escondido',
#  'alice springs',
#  'pazardzik',
#  'kaka',
#  'arona',
#  'grand river south east',
#  'rosh pinna',
#  'krasnoselkup',
#  'yulara',
#  'ust-ilimsk',
#  'myaundzha',
#  'black river',
#  'carutapera',
#  'tura',
#  'greenville',
#  'makakilo city',
#  'beringovskiy',
#  'namatanai',
#  'katsuura',
#  'moerai',
#  'naze',
#  'alotau',
#  'goes',
#  'marsa matruh',
#  'pacific grove',
#  'nalgonda',
#  'frontera',
#  'san policarpo',
#  'sillamae',
#  'salaga',
#  'vyazemskiy',
#  'goundam',
#  'inhambane',
#  'maniitsoq',
#  'vagur',
#  'ewo',
#  'nong khai',
#  'padong',
#  'kaeo',
#  'prabumulih',
#  'bagnan',
#  'los llanos de aridane',
#  'harwich',
#  'mocorito',
#  'bull savanna',
#  'kachikau',
#  'zhezkazgan',
#  'rusape',
#  'wad rawah',
#  'shaunavon',
#  'fortuna',
#  'andenes',
#  'quijingue',
#  'ust-kulom',
#  'karratha',
#  'zabolotovka',
#  'kawalu',
#  'mwense',
#  'totesti',
#  'sabzevar',
#  'tumannyy',
#  'yendi',
#  'dolbeau',
#  'gazli',
#  'mugla',
#  'swedru',
#  'lavrentiya',
#  'springdale',
#  'arzgir',
#  'mecca',
#  'rudbar',
#  'jacareacanga',
#  'simav',
#  'tieli',
#  'jabinyanah',
#  'maxixe',
#  'temaraia',
#  'luganville',
#  'sandakan',
#  'sonipat',
#  'grants',
#  'mehamn',
#  'tubruq',
#  'shenjiamen',
#  'areosa',
#  'kristiansund',
#  'capao da canoa',
#  'ebano',
#  'antofagasta',
#  'emerald',
#  'khasan',
#  'pizarro',
#  'ilulissat',
#  'kushima',
#  'nizwa',
#  'dali',
#  'sedelnikovo',
#  'tautira',
#  'aginskoye',
#  'kabanjahe',
#  'qasigiannguit',
#  'bella vista',
#  'semey',
#  'vydrino',
#  'sao gabriel da cachoeira',
#  'tilichiki',
#  'tabiauea',
#  'maraa',
#  'yerbogachen',
#  'jiuquan',
#  'mehran',
#  'nijar',
#  'entre rios',
#  'nishihara',
#  'bunia',
#  'sumter',
#  'richards bay',
#  'beaverlodge',
#  'deputatskiy',
#  'milan',
#  'meadow lake',
#  'brownwood',
#  'zhangye',
#  'fez',
#  'meulaboh',
#  'qurayyat',
#  'kui buri',
#  'platanos',
#  'kosh-agach',
#  'dicamay',
#  'letka',
#  'gambela',
#  'bara',
#  'wanxian',
#  'baykit',
#  'prado',
#  'viedma',
#  'snasa',
#  'fianga',
#  'tahoua',
#  'novopokrovka',
#  'barranco',
#  'ostuman',
#  'paradwip',
#  'nantucket',
#  'manakara',
#  'tomatlan',
#  'balkanabat',
#  'shingu',
#  'porto torres',
#  'salalah',
#  'cozumel',
#  'ramasukha',
#  'monclova',
#  'barretos',
#  'acapulco',
#  'rundu',
#  'tazovskiy',
#  'hirara',
#  'laguna',
#  'gilgit',
#  'poum',
#  'nkowakowa',
#  'ramhormoz',
#  'jilib',
#  'bethlehem',
#  'madanapalle',
#  'byron bay',
#  'fairview',
#  'imeni babushkina',
#  'bhadrachalam',
#  'havelock',
#  'nabire',
#  'bolshiye chapurniki',
#  'hayato',
#  'saint-michel-des-saints',
#  'alofi',
#  'san-pedro',
#  'taoudenni',
#  'goderich',
#  'kirakira',
#  'katima mulilo',
#  'placido de castro',
#  'chulman',
#  'nuuk',
#  'menongue',
#  'coari',
#  'pitimbu',
#  'abu kamal',
#  'malakal',
#  'erenhot',
#  'miles city',
#  'sampit',
#  'okhotsk',
#  'karasburg',
#  'florianopolis',
#  'axim',
#  'amboasary',
#  'zhigalovo',
#  'sikasso',
#  'bilibino',
#  'swan hill',
#  'kieta',
#  'abu zabad',
#  'sharlyk',
#  'saldanha',
#  'huicungo',
#  'ranong',
#  'pocatello',
#  'hamilton',
#  'sooke',
#  'bria',
#  'parsons',
#  'ilhabela',
#  'novyy urgal',
#  'gao',
#  'ozgon',
#  'emilio carranza',
#  'skjervoy',
#  'port hardy',
#  'aykhal',
#  'phan rang',
#  'houston',
#  'dipkarpaz',
#  'haapu',
#  'leshukonskoye',
#  'havre-saint-pierre',
#  'cervo',
#  'de aar',
#  'tessalit',
#  'philadelphia',
#  'falmouth',
#  'batemans bay',
#  'belyy yar',
#  'cumpas',
#  'port keats',
#  'jumla',
#  'pedasi',
#  'lakatoro',
#  'rovaniemi',
#  'teahupoo',
#  'shubarshi',
#  'straumen',
#  'hoi an',
#  'kungurtug',
#  'kralendijk',
#  'chengde',
#  'lagunillas',
#  'ponerihouen',
#  'noumea',
#  'auki',
#  'lingao',
#  'buala',
#  'muli',
#  'nurota',
#  'diban',
#  'yongan',
#  'serov',
#  'chuy',
#  'kaukauna',
#  'phayakkhaphum phisai',
#  'tunduru',
#  'piopio',
#  'russell',
#  'loreto',
#  'bongandanga',
#  'diego de almagro',
#  'marzuq',
#  'san matias',
#  'rantepao',
#  'ouallam',
#  'tubbergen',
#  'haines junction',
#  'kutum',
#  'zavallya',
#  'nizhniy kuranakh',
#  'reinosa',
#  'alpena',
#  'kitakata',
#  'batagay-alyta',
#  'mocuba',
#  'paita',
#  'sao raimundo das mangabeiras',
#  'husavik',
#  'gidam',
#  'port hedland',
#  'ovre ardal',
#  'biak',
#  'salinopolis',
#  'chiredzi',
#  'bulgan',
#  'sakaiminato',
#  'hutang',
#  'ucluelet',
#  'ouango',
#  'campbell river',
#  'agogo',
#  'bilma',
#  'altay']

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create endpoint URL with each city.
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 135.4833, 'lat': -3.3667},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 83.28,
#   'feels_like': 91.38,
#   'temp_min': 83.28,
#   'temp_max': 83.28,
#   'pressure': 1011,
#   'humidity': 78,
#   'sea_level': 1011,
#   'grnd_level': 1010},
#  'visibility': 10000,
#  'wind': {'speed': 2.51, 'deg': 266, 'gust': 2.95},
#  'clouds': {'all': 99},
#  'dt': 1650248930,
#  'sys': {'country': 'ID', 'sunrise': 1650228988, 'sunset': 1650272289},
#  'timezone': 32400,
#  'id': 1634614,
#  'name': 'Nabire',
#  'cod': 200}

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["main"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thunder bay
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | ust-ishim
# Processing Record 6 of Set 1 | urumqi
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | ciudad bolivar
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | cayenne
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | kenora
# Processing Record 19 of Set 1 | langsa
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | carballo
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | lanzhou
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | san jeronimo
# Processing Record 27 of Set 1 | moron
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | miri
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | broken hill
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | port augusta
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | atar
# Processing Record 38 of Set 1 | warrnambool
# Processing Record 39 of Set 1 | liverpool
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | port blair
# Processing Record 42 of Set 1 | vardo
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | labuhan
# Processing Record 45 of Set 1 | port moresby
# Processing Record 46 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | pringsewu
# Processing Record 48 of Set 1 | rojhan
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | mae hong son
# Processing Record 1 of Set 2 | maragogi
# Processing Record 2 of Set 2 | taldan
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | davila
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | donja dubica
# Processing Record 11 of Set 2 | la ronge
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | katobu
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | grand-santi
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | rocha
# Processing Record 22 of Set 2 | fallon
# Processing Record 23 of Set 2 | cocorit
# Processing Record 24 of Set 2 | marovoay
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | saint-joseph
# Processing Record 27 of Set 2 | yumen
# Processing Record 28 of Set 2 | bolgatanga
# Processing Record 29 of Set 2 | imbituba
# Processing Record 30 of Set 2 | maarianhamina
# Processing Record 31 of Set 2 | caconda
# Processing Record 32 of Set 2 | la orilla
# Processing Record 33 of Set 2 | kamskiye polyany
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | hokitika
# Processing Record 37 of Set 2 | songea
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | huarmey
# Processing Record 41 of Set 2 | paamiut
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | changji
# Processing Record 44 of Set 2 | rab
# City not found. Skipping...
# Processing Record 45 of Set 2 | haukipudas
# Processing Record 46 of Set 2 | baft
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | asyut
# Processing Record 49 of Set 2 | krasnaya zarya
# Processing Record 50 of Set 2 | dongsheng
# Processing Record 1 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | paranagua
# Processing Record 3 of Set 3 | odweyne
# Processing Record 4 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | tevaitoa
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | inirida
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | college
# Processing Record 12 of Set 3 | sochi
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | nagorsk
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | bonoua
# Processing Record 19 of Set 3 | hobyo
# Processing Record 20 of Set 3 | volax
# Processing Record 21 of Set 3 | komyshuvakha
# Processing Record 22 of Set 3 | chitral
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | vysokogornyy
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | les cayes
# Processing Record 28 of Set 3 | gandai
# Processing Record 29 of Set 3 | san patricio
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 3 | bressuire
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | anuchino
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | kirensk
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | willowmore
# Processing Record 44 of Set 3 | mukhen
# Processing Record 45 of Set 3 | mareeba
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | sao geraldo do araguaia
# Processing Record 48 of Set 3 | kachug
# Processing Record 49 of Set 3 | khargapur
# Processing Record 50 of Set 3 | chumikan
# Processing Record 1 of Set 4 | camacha
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | hirosaki
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | dakar
# Processing Record 6 of Set 4 | thinadhoo
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | canutama
# Processing Record 9 of Set 4 | nome
# Processing Record 10 of Set 4 | inuvik
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | lata
# Processing Record 13 of Set 4 | dingle
# Processing Record 14 of Set 4 | manta
# Processing Record 15 of Set 4 | eureka
# Processing Record 16 of Set 4 | america dourada
# Processing Record 17 of Set 4 | formosa do rio preto
# Processing Record 18 of Set 4 | khatanga
# Processing Record 19 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 4 | sur
# Processing Record 21 of Set 4 | asmara
# Processing Record 22 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | malabo
# Processing Record 26 of Set 4 | port alfred
# Processing Record 27 of Set 4 | vao
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | muros
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | mahon
# Processing Record 34 of Set 4 | grand gaube
# Processing Record 35 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 38 of Set 4 | zeya
# Processing Record 39 of Set 4 | ganzhou
# Processing Record 40 of Set 4 | nelson bay
# Processing Record 41 of Set 4 | anadyr
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | revelstoke
# Processing Record 44 of Set 4 | atambua
# Processing Record 45 of Set 4 | aksarayskiy
# Processing Record 46 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 4 | roseburg
# Processing Record 48 of Set 4 | henties bay
# Processing Record 49 of Set 4 | caetite
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | korla
# Processing Record 2 of Set 5 | raisen
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | sinazongwe
# Processing Record 5 of Set 5 | gazanjyk
# Processing Record 6 of Set 5 | tambopata
# Processing Record 7 of Set 5 | burica
# City not found. Skipping...
# Processing Record 8 of Set 5 | pisco
# Processing Record 9 of Set 5 | avera
# Processing Record 10 of Set 5 | ketchikan
# Processing Record 11 of Set 5 | tamboril
# Processing Record 12 of Set 5 | trzacka rastela
# Processing Record 13 of Set 5 | rafraf
# Processing Record 14 of Set 5 | grand forks
# Processing Record 15 of Set 5 | zhigansk
# Processing Record 16 of Set 5 | los algarrobos
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | bako
# Processing Record 19 of Set 5 | bengkulu
# Processing Record 20 of Set 5 | ayr
# Processing Record 21 of Set 5 | sembakung
# Processing Record 22 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | mbinga
# Processing Record 25 of Set 5 | lorengau
# Processing Record 26 of Set 5 | novaya bryan
# Processing Record 27 of Set 5 | sychevka
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | amancio
# City not found. Skipping...
# Processing Record 30 of Set 5 | sokolo
# Processing Record 31 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | dikson
# Processing Record 34 of Set 5 | bowen
# Processing Record 35 of Set 5 | mercedes
# Processing Record 36 of Set 5 | sumbe
# Processing Record 37 of Set 5 | binzhou
# Processing Record 38 of Set 5 | okato
# Processing Record 39 of Set 5 | zhongshu
# Processing Record 40 of Set 5 | maracas
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | ginda
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | ostrovnoy
# Processing Record 45 of Set 5 | tongzi
# Processing Record 46 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 5 | coihaique
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | forestville
# Processing Record 1 of Set 6 | mizdah
# Processing Record 2 of Set 6 | zhytomyr
# Processing Record 3 of Set 6 | pangody
# Processing Record 4 of Set 6 | kalmunai
# Processing Record 5 of Set 6 | xichang
# Processing Record 6 of Set 6 | balao
# Processing Record 7 of Set 6 | mwinilunga
# Processing Record 8 of Set 6 | calama
# Processing Record 9 of Set 6 | mount kisco
# Processing Record 10 of Set 6 | shwebo
# Processing Record 11 of Set 6 | lyudinovo
# Processing Record 12 of Set 6 | deyang
# Processing Record 13 of Set 6 | sabang
# Processing Record 14 of Set 6 | upernavik
# Processing Record 15 of Set 6 | polunochnoye
# Processing Record 16 of Set 6 | kununurra
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | borogontsy
# Processing Record 19 of Set 6 | linxia
# Processing Record 20 of Set 6 | sinnamary
# Processing Record 21 of Set 6 | kribi
# Processing Record 22 of Set 6 | saint-pierre
# Processing Record 23 of Set 6 | praia
# Processing Record 24 of Set 6 | paracuru
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | ermelo
# Processing Record 28 of Set 6 | waipawa
# Processing Record 29 of Set 6 | leh
# Processing Record 30 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | alihe
# Processing Record 34 of Set 6 | pangnirtung
# Processing Record 35 of Set 6 | maryville
# Processing Record 36 of Set 6 | ponta do sol
# Processing Record 37 of Set 6 | chernyshevskiy
# Processing Record 38 of Set 6 | kenai
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | chadan
# Processing Record 42 of Set 6 | anchorage
# Processing Record 43 of Set 6 | kikwit
# Processing Record 44 of Set 6 | seoul
# Processing Record 45 of Set 6 | benguela
# Processing Record 46 of Set 6 | pekan
# Processing Record 47 of Set 6 | riachao
# Processing Record 48 of Set 6 | port lincoln
# Processing Record 49 of Set 6 | high level
# Processing Record 50 of Set 6 | emborion
# Processing Record 1 of Set 7 | carahue
# Processing Record 2 of Set 7 | barsovo
# Processing Record 3 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 7 | muisne
# Processing Record 5 of Set 7 | clyde river
# Processing Record 6 of Set 7 | fernandopolis
# Processing Record 7 of Set 7 | chalmette
# Processing Record 8 of Set 7 | broome
# Processing Record 9 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 7 | komsomolskiy
# Processing Record 11 of Set 7 | southbridge
# Processing Record 12 of Set 7 | sechura
# Processing Record 13 of Set 7 | gizo
# Processing Record 14 of Set 7 | nouadhibou
# Processing Record 15 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 7 | port said
# Processing Record 17 of Set 7 | mokhsogollokh
# Processing Record 18 of Set 7 | bayanday
# Processing Record 19 of Set 7 | brae
# Processing Record 20 of Set 7 | igunga
# Processing Record 21 of Set 7 | olafsvik
# Processing Record 22 of Set 7 | kholodnyy
# Processing Record 23 of Set 7 | comodoro rivadavia
# Processing Record 24 of Set 7 | wismar
# Processing Record 25 of Set 7 | colombia
# Processing Record 26 of Set 7 | santa comba
# Processing Record 27 of Set 7 | malaryta
# Processing Record 28 of Set 7 | uyuni
# Processing Record 29 of Set 7 | oistins
# Processing Record 30 of Set 7 | ahipara
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | sungai besar
# Processing Record 34 of Set 7 | troitskoye
# Processing Record 35 of Set 7 | nieuw amsterdam
# Processing Record 36 of Set 7 | tiksi
# Processing Record 37 of Set 7 | waingapu
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | billings
# Processing Record 40 of Set 7 | lasa
# Processing Record 41 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 42 of Set 7 | inta
# Processing Record 43 of Set 7 | yeppoon
# Processing Record 44 of Set 7 | provideniya
# Processing Record 45 of Set 7 | bathsheba
# Processing Record 46 of Set 7 | bandarbeyla
# Processing Record 47 of Set 7 | inongo
# Processing Record 48 of Set 7 | padang
# Processing Record 49 of Set 7 | jining
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | binga
# Processing Record 2 of Set 8 | mendi
# Processing Record 3 of Set 8 | botou
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | asau
# Processing Record 6 of Set 8 | bridlington
# Processing Record 7 of Set 8 | cobija
# Processing Record 8 of Set 8 | evensk
# Processing Record 9 of Set 8 | marion
# Processing Record 10 of Set 8 | ayagoz
# Processing Record 11 of Set 8 | archidona
# Processing Record 12 of Set 8 | fort nelson
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | teguldet
# Processing Record 15 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 8 | bosaso
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | linjiang
# Processing Record 19 of Set 8 | punta gorda
# Processing Record 20 of Set 8 | faya
# Processing Record 21 of Set 8 | talcahuano
# Processing Record 22 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | kodiak
# Processing Record 25 of Set 8 | mount isa
# Processing Record 26 of Set 8 | asosa
# Processing Record 27 of Set 8 | dauphin
# Processing Record 28 of Set 8 | guarapari
# Processing Record 29 of Set 8 | mao
# Processing Record 30 of Set 8 | dunmore town
# Processing Record 31 of Set 8 | voiron
# Processing Record 32 of Set 8 | flinders
# Processing Record 33 of Set 8 | talisay
# Processing Record 34 of Set 8 | sile
# Processing Record 35 of Set 8 | nicoya
# Processing Record 36 of Set 8 | artvin
# Processing Record 37 of Set 8 | mitsamiouli
# Processing Record 38 of Set 8 | whitehorse
# Processing Record 39 of Set 8 | sao filipe
# Processing Record 40 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 8 | tenenkou
# Processing Record 42 of Set 8 | neiafu
# Processing Record 43 of Set 8 | tucurui
# Processing Record 44 of Set 8 | baghdad
# Processing Record 45 of Set 8 | luderitz
# Processing Record 46 of Set 8 | minna
# Processing Record 47 of Set 8 | homer
# Processing Record 48 of Set 8 | yatou
# Processing Record 49 of Set 8 | imatra
# Processing Record 50 of Set 8 | pundaguitan
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | nikel
# Processing Record 3 of Set 9 | guerrero negro
# Processing Record 4 of Set 9 | jinchang
# Processing Record 5 of Set 9 | chizhou
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 9 | roald
# Processing Record 9 of Set 9 | saint-georges
# Processing Record 10 of Set 9 | tiberias
# Processing Record 11 of Set 9 | tuban
# Processing Record 12 of Set 9 | ajdabiya
# Processing Record 13 of Set 9 | almaznyy
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 9 | noyabrsk
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 9 | bikin
# Processing Record 20 of Set 9 | cinisi
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | turukhansk
# Processing Record 23 of Set 9 | balsas
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | camocim
# Processing Record 26 of Set 9 | sao joao da barra
# Processing Record 27 of Set 9 | dunedin
# Processing Record 28 of Set 9 | ribeira grande
# Processing Record 29 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 9 | cidreira
# Processing Record 31 of Set 9 | narsaq
# Processing Record 32 of Set 9 | pavilosta
# Processing Record 33 of Set 9 | te anau
# Processing Record 34 of Set 9 | ruteng
# Processing Record 35 of Set 9 | thessalon
# Processing Record 36 of Set 9 | estevan
# Processing Record 37 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 9 | octeville
# Processing Record 39 of Set 9 | honningsvag
# Processing Record 40 of Set 9 | kasungu
# Processing Record 41 of Set 9 | spa
# Processing Record 42 of Set 9 | at-bashi
# Processing Record 43 of Set 9 | oktyabrskoye
# Processing Record 44 of Set 9 | portland
# Processing Record 45 of Set 9 | harper
# Processing Record 46 of Set 9 | adoni
# Processing Record 47 of Set 9 | kasongo-lunda
# Processing Record 48 of Set 9 | road town
# Processing Record 49 of Set 9 | flin flon
# Processing Record 50 of Set 9 | north bend
# Processing Record 1 of Set 10 | presidente medici
# Processing Record 2 of Set 10 | chingirlau
# Processing Record 3 of Set 10 | gat
# Processing Record 4 of Set 10 | vestmannaeyjar
# Processing Record 5 of Set 10 | kalundborg
# Processing Record 6 of Set 10 | playa vicente
# Processing Record 7 of Set 10 | yar-sale
# Processing Record 8 of Set 10 | honiara
# Processing Record 9 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 10 | veraval
# Processing Record 11 of Set 10 | plouzane
# Processing Record 12 of Set 10 | ambon
# Processing Record 13 of Set 10 | hailar
# Processing Record 14 of Set 10 | vejprty
# Processing Record 15 of Set 10 | fairbanks
# Processing Record 16 of Set 10 | nara
# Processing Record 17 of Set 10 | doraha
# Processing Record 18 of Set 10 | valparaiso
# Processing Record 19 of Set 10 | cayeli
# Processing Record 20 of Set 10 | stokmarknes
# Processing Record 21 of Set 10 | bondo
# Processing Record 22 of Set 10 | viana
# Processing Record 23 of Set 10 | hovd
# Processing Record 24 of Set 10 | svirsk
# Processing Record 25 of Set 10 | yaan
# Processing Record 26 of Set 10 | bafq
# Processing Record 27 of Set 10 | suoyarvi
# Processing Record 28 of Set 10 | chandler
# Processing Record 29 of Set 10 | mahibadhoo
# Processing Record 30 of Set 10 | sitka
# Processing Record 31 of Set 10 | luanda
# Processing Record 32 of Set 10 | tambovka
# Processing Record 33 of Set 10 | cananeia
# Processing Record 34 of Set 10 | labytnangi
# Processing Record 35 of Set 10 | monterey
# Processing Record 36 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 10 | ballina
# Processing Record 38 of Set 10 | horni benesov
# Processing Record 39 of Set 10 | dangriga
# Processing Record 40 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 10 | wyszkow
# Processing Record 42 of Set 10 | adrar
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | marystown
# Processing Record 45 of Set 10 | mogadishu
# Processing Record 46 of Set 10 | muroto
# Processing Record 47 of Set 10 | sao miguel do araguaia
# Processing Record 48 of Set 10 | winslow
# Processing Record 49 of Set 10 | manzil salim
# Processing Record 50 of Set 10 | khor
# Processing Record 1 of Set 11 | puerto escondido
# Processing Record 2 of Set 11 | alice springs
# Processing Record 3 of Set 11 | pazardzik
# City not found. Skipping...
# Processing Record 4 of Set 11 | kaka
# Processing Record 5 of Set 11 | arona
# Processing Record 6 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 11 | rosh pinna
# Processing Record 8 of Set 11 | krasnoselkup
# Processing Record 9 of Set 11 | yulara
# Processing Record 10 of Set 11 | ust-ilimsk
# Processing Record 11 of Set 11 | myaundzha
# Processing Record 12 of Set 11 | black river
# Processing Record 13 of Set 11 | carutapera
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | greenville
# Processing Record 16 of Set 11 | makakilo city
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | namatanai
# Processing Record 19 of Set 11 | katsuura
# Processing Record 20 of Set 11 | moerai
# Processing Record 21 of Set 11 | naze
# Processing Record 22 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 11 | goes
# Processing Record 24 of Set 11 | marsa matruh
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | nalgonda
# Processing Record 27 of Set 11 | frontera
# Processing Record 28 of Set 11 | san policarpo
# Processing Record 29 of Set 11 | sillamae
# Processing Record 30 of Set 11 | salaga
# Processing Record 31 of Set 11 | vyazemskiy
# Processing Record 32 of Set 11 | goundam
# Processing Record 33 of Set 11 | inhambane
# Processing Record 34 of Set 11 | maniitsoq
# Processing Record 35 of Set 11 | vagur
# Processing Record 36 of Set 11 | ewo
# Processing Record 37 of Set 11 | nong khai
# Processing Record 38 of Set 11 | padong
# Processing Record 39 of Set 11 | kaeo
# Processing Record 40 of Set 11 | prabumulih
# Processing Record 41 of Set 11 | bagnan
# Processing Record 42 of Set 11 | los llanos de aridane
# Processing Record 43 of Set 11 | harwich
# Processing Record 44 of Set 11 | mocorito
# Processing Record 45 of Set 11 | bull savanna
# Processing Record 46 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 47 of Set 11 | zhezkazgan
# Processing Record 48 of Set 11 | rusape
# Processing Record 49 of Set 11 | wad rawah
# Processing Record 50 of Set 11 | shaunavon
# Processing Record 1 of Set 12 | fortuna
# Processing Record 2 of Set 12 | andenes
# Processing Record 3 of Set 12 | quijingue
# Processing Record 4 of Set 12 | ust-kulom
# Processing Record 5 of Set 12 | karratha
# Processing Record 6 of Set 12 | zabolotovka
# Processing Record 7 of Set 12 | kawalu
# Processing Record 8 of Set 12 | mwense
# Processing Record 9 of Set 12 | totesti
# Processing Record 10 of Set 12 | sabzevar
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | yendi
# Processing Record 13 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 12 | gazli
# Processing Record 15 of Set 12 | mugla
# Processing Record 16 of Set 12 | swedru
# Processing Record 17 of Set 12 | lavrentiya
# Processing Record 18 of Set 12 | springdale
# Processing Record 19 of Set 12 | arzgir
# Processing Record 20 of Set 12 | mecca
# Processing Record 21 of Set 12 | rudbar
# Processing Record 22 of Set 12 | jacareacanga
# Processing Record 23 of Set 12 | simav
# Processing Record 24 of Set 12 | tieli
# Processing Record 25 of Set 12 | jabinyanah
# Processing Record 26 of Set 12 | maxixe
# Processing Record 27 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 12 | luganville
# Processing Record 29 of Set 12 | sandakan
# Processing Record 30 of Set 12 | sonipat
# Processing Record 31 of Set 12 | grants
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 12 | shenjiamen
# Processing Record 35 of Set 12 | areosa
# Processing Record 36 of Set 12 | kristiansund
# Processing Record 37 of Set 12 | capao da canoa
# Processing Record 38 of Set 12 | ebano
# City not found. Skipping...
# Processing Record 39 of Set 12 | antofagasta
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | khasan
# Processing Record 42 of Set 12 | pizarro
# Processing Record 43 of Set 12 | ilulissat
# Processing Record 44 of Set 12 | kushima
# Processing Record 45 of Set 12 | nizwa
# Processing Record 46 of Set 12 | dali
# Processing Record 47 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 12 | tautira
# Processing Record 49 of Set 12 | aginskoye
# Processing Record 50 of Set 12 | kabanjahe
# Processing Record 1 of Set 13 | qasigiannguit
# Processing Record 2 of Set 13 | bella vista
# Processing Record 3 of Set 13 | semey
# Processing Record 4 of Set 13 | vydrino
# Processing Record 5 of Set 13 | sao gabriel da cachoeira
# Processing Record 6 of Set 13 | tilichiki
# Processing Record 7 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 13 | maraa
# Processing Record 9 of Set 13 | yerbogachen
# Processing Record 10 of Set 13 | jiuquan
# Processing Record 11 of Set 13 | mehran
# Processing Record 12 of Set 13 | nijar
# Processing Record 13 of Set 13 | entre rios
# Processing Record 14 of Set 13 | nishihara
# Processing Record 15 of Set 13 | bunia
# Processing Record 16 of Set 13 | sumter
# Processing Record 17 of Set 13 | richards bay
# Processing Record 18 of Set 13 | beaverlodge
# Processing Record 19 of Set 13 | deputatskiy
# Processing Record 20 of Set 13 | milan
# Processing Record 21 of Set 13 | meadow lake
# Processing Record 22 of Set 13 | brownwood
# Processing Record 23 of Set 13 | zhangye
# Processing Record 24 of Set 13 | fez
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | qurayyat
# Processing Record 27 of Set 13 | kui buri
# Processing Record 28 of Set 13 | platanos
# Processing Record 29 of Set 13 | kosh-agach
# Processing Record 30 of Set 13 | dicamay
# Processing Record 31 of Set 13 | letka
# Processing Record 32 of Set 13 | gambela
# Processing Record 33 of Set 13 | bara
# Processing Record 34 of Set 13 | wanxian
# Processing Record 35 of Set 13 | baykit
# Processing Record 36 of Set 13 | prado
# Processing Record 37 of Set 13 | viedma
# Processing Record 38 of Set 13 | snasa
# Processing Record 39 of Set 13 | fianga
# City not found. Skipping...
# Processing Record 40 of Set 13 | tahoua
# Processing Record 41 of Set 13 | novopokrovka
# Processing Record 42 of Set 13 | barranco
# Processing Record 43 of Set 13 | ostuman
# City not found. Skipping...
# Processing Record 44 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 13 | nantucket
# Processing Record 46 of Set 13 | manakara
# Processing Record 47 of Set 13 | tomatlan
# Processing Record 48 of Set 13 | balkanabat
# Processing Record 49 of Set 13 | shingu
# Processing Record 50 of Set 13 | porto torres
# Processing Record 1 of Set 14 | salalah
# Processing Record 2 of Set 14 | cozumel
# Processing Record 3 of Set 14 | ramasukha
# City not found. Skipping...
# Processing Record 4 of Set 14 | monclova
# Processing Record 5 of Set 14 | barretos
# Processing Record 6 of Set 14 | acapulco
# Processing Record 7 of Set 14 | rundu
# Processing Record 8 of Set 14 | tazovskiy
# Processing Record 9 of Set 14 | hirara
# Processing Record 10 of Set 14 | laguna
# Processing Record 11 of Set 14 | gilgit
# Processing Record 12 of Set 14 | poum
# Processing Record 13 of Set 14 | nkowakowa
# Processing Record 14 of Set 14 | ramhormoz
# Processing Record 15 of Set 14 | jilib
# Processing Record 16 of Set 14 | bethlehem
# Processing Record 17 of Set 14 | madanapalle
# Processing Record 18 of Set 14 | byron bay
# Processing Record 19 of Set 14 | fairview
# Processing Record 20 of Set 14 | imeni babushkina
# Processing Record 21 of Set 14 | bhadrachalam
# Processing Record 22 of Set 14 | havelock
# Processing Record 23 of Set 14 | nabire
# Processing Record 24 of Set 14 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 25 of Set 14 | hayato
# City not found. Skipping...
# Processing Record 26 of Set 14 | saint-michel-des-saints
# Processing Record 27 of Set 14 | alofi
# Processing Record 28 of Set 14 | san-pedro
# Processing Record 29 of Set 14 | taoudenni
# Processing Record 30 of Set 14 | goderich
# Processing Record 31 of Set 14 | kirakira
# Processing Record 32 of Set 14 | katima mulilo
# Processing Record 33 of Set 14 | placido de castro
# Processing Record 34 of Set 14 | chulman
# Processing Record 35 of Set 14 | nuuk
# Processing Record 36 of Set 14 | menongue
# Processing Record 37 of Set 14 | coari
# Processing Record 38 of Set 14 | pitimbu
# Processing Record 39 of Set 14 | abu kamal
# Processing Record 40 of Set 14 | malakal
# Processing Record 41 of Set 14 | erenhot
# Processing Record 42 of Set 14 | miles city
# Processing Record 43 of Set 14 | sampit
# Processing Record 44 of Set 14 | okhotsk
# Processing Record 45 of Set 14 | karasburg
# Processing Record 46 of Set 14 | florianopolis
# Processing Record 47 of Set 14 | axim
# Processing Record 48 of Set 14 | amboasary
# Processing Record 49 of Set 14 | zhigalovo
# Processing Record 50 of Set 14 | sikasso
# Processing Record 1 of Set 15 | bilibino
# Processing Record 2 of Set 15 | swan hill
# Processing Record 3 of Set 15 | kieta
# Processing Record 4 of Set 15 | abu zabad
# Processing Record 5 of Set 15 | sharlyk
# Processing Record 6 of Set 15 | saldanha
# Processing Record 7 of Set 15 | huicungo
# Processing Record 8 of Set 15 | ranong
# Processing Record 9 of Set 15 | pocatello
# Processing Record 10 of Set 15 | hamilton
# Processing Record 11 of Set 15 | sooke
# Processing Record 12 of Set 15 | bria
# Processing Record 13 of Set 15 | parsons
# Processing Record 14 of Set 15 | ilhabela
# Processing Record 15 of Set 15 | novyy urgal
# Processing Record 16 of Set 15 | gao
# Processing Record 17 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 15 | emilio carranza
# Processing Record 19 of Set 15 | skjervoy
# Processing Record 20 of Set 15 | port hardy
# Processing Record 21 of Set 15 | aykhal
# Processing Record 22 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 15 | houston
# Processing Record 24 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 25 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 26 of Set 15 | leshukonskoye
# Processing Record 27 of Set 15 | havre-saint-pierre
# Processing Record 28 of Set 15 | cervo
# Processing Record 29 of Set 15 | de aar
# Processing Record 30 of Set 15 | tessalit
# Processing Record 31 of Set 15 | philadelphia
# Processing Record 32 of Set 15 | falmouth
# Processing Record 33 of Set 15 | batemans bay
# Processing Record 34 of Set 15 | belyy yar
# Processing Record 35 of Set 15 | cumpas
# Processing Record 36 of Set 15 | port keats
# Processing Record 37 of Set 15 | jumla
# Processing Record 38 of Set 15 | pedasi
# Processing Record 39 of Set 15 | lakatoro
# Processing Record 40 of Set 15 | rovaniemi
# Processing Record 41 of Set 15 | teahupoo
# Processing Record 42 of Set 15 | shubarshi
# Processing Record 43 of Set 15 | straumen
# Processing Record 44 of Set 15 | hoi an
# Processing Record 45 of Set 15 | kungurtug
# Processing Record 46 of Set 15 | kralendijk
# Processing Record 47 of Set 15 | chengde
# Processing Record 48 of Set 15 | lagunillas
# Processing Record 49 of Set 15 | ponerihouen
# Processing Record 50 of Set 15 | noumea
# Processing Record 1 of Set 16 | auki
# Processing Record 2 of Set 16 | lingao
# Processing Record 3 of Set 16 | buala
# Processing Record 4 of Set 16 | muli
# Processing Record 5 of Set 16 | nurota
# Processing Record 6 of Set 16 | diban
# Processing Record 7 of Set 16 | yongan
# Processing Record 8 of Set 16 | serov
# Processing Record 9 of Set 16 | chuy
# Processing Record 10 of Set 16 | kaukauna
# Processing Record 11 of Set 16 | phayakkhaphum phisai
# Processing Record 12 of Set 16 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 16 | piopio
# Processing Record 14 of Set 16 | russell
# Processing Record 15 of Set 16 | loreto
# Processing Record 16 of Set 16 | bongandanga
# Processing Record 17 of Set 16 | diego de almagro
# Processing Record 18 of Set 16 | marzuq
# Processing Record 19 of Set 16 | san matias
# Processing Record 20 of Set 16 | rantepao
# Processing Record 21 of Set 16 | ouallam
# Processing Record 22 of Set 16 | tubbergen
# Processing Record 23 of Set 16 | haines junction
# Processing Record 24 of Set 16 | kutum
# Processing Record 25 of Set 16 | zavallya
# Processing Record 26 of Set 16 | nizhniy kuranakh
# Processing Record 27 of Set 16 | reinosa
# Processing Record 28 of Set 16 | alpena
# Processing Record 29 of Set 16 | kitakata
# Processing Record 30 of Set 16 | batagay-alyta
# Processing Record 31 of Set 16 | mocuba
# Processing Record 32 of Set 16 | paita
# Processing Record 33 of Set 16 | sao raimundo das mangabeiras
# Processing Record 34 of Set 16 | husavik
# Processing Record 35 of Set 16 | gidam
# Processing Record 36 of Set 16 | port hedland
# Processing Record 37 of Set 16 | ovre ardal
# Processing Record 38 of Set 16 | biak
# Processing Record 39 of Set 16 | salinopolis
# Processing Record 40 of Set 16 | chiredzi
# Processing Record 41 of Set 16 | bulgan
# Processing Record 42 of Set 16 | sakaiminato
# Processing Record 43 of Set 16 | hutang
# Processing Record 44 of Set 16 | ucluelet
# Processing Record 45 of Set 16 | ouango
# Processing Record 46 of Set 16 | campbell river
# Processing Record 47 of Set 16 | agogo
# Processing Record 48 of Set 16 | bilma
# Processing Record 49 of Set 16 | altay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 734

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thunder Bay  48.4001  -89.3168     29.28        83         100
# 1     Punta Arenas -53.1500  -70.9167     42.91        81          75
# 2        Hithadhoo  -0.6000   73.0833     82.99        75          29
# 3          Rikitea -23.1203 -134.9692     78.48        63           2
# 4        Ust-Ishim  57.6935   71.1665     32.72        74          88
# 5           Urumqi  43.8010   87.6005     67.15         7           0
# 6             Lebu -37.6167  -73.6500     52.25        91          21
# 7  Arraial Do Cabo -22.9661  -42.0278     72.18        71           0
# 8        Cape Town -33.9258   18.4232     61.92        80           0
# 9            Airai  -8.9266  125.4092     73.99        60         100
#
#    Wind Speed Current Description Country                 Date
# 0       10.36              Clouds      CA  2022-04-18 02:27:14
# 1        5.75              Clouds      CL  2022-04-18 02:28:36
# 2       10.40              Clouds      MV  2022-04-18 02:28:18
# 3       10.27               Clear      PF  2022-04-18 02:28:51
# 4        4.18              Clouds      RU  2022-04-18 02:28:51
# 5       13.42               Clear      CN  2022-04-18 02:24:02
# 6        7.14              Clouds      CL  2022-04-18 02:27:05
# 7        7.38               Clear      BR  2022-04-18 02:25:48
# 8        9.22               Clear      ZA  2022-04-18 02:28:15
# 9        1.41              Clouds      TL  2022-04-18 02:28:52

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thunder Bay      CA  48.4001  -89.3168     29.28        83         100
# 1     Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
# 2        Hithadhoo      MV  -0.6000   73.0833     82.99        75          29
# 3          Rikitea      PF -23.1203 -134.9692     78.48        63           2
# 4        Ust-Ishim      RU  57.6935   71.1665     32.72        74          88
# 5           Urumqi      CN  43.8010   87.6005     67.15         7           0
# 6             Lebu      CL -37.6167  -73.6500     52.25        91          21
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     72.18        71           0
# 8        Cape Town      ZA -33.9258   18.4232     61.92        80           0
# 9            Airai      TL  -8.9266  125.4092     73.99        60         100
#
#    Wind Speed Current Description
# 0       10.36              Clouds
# 1        5.75              Clouds
# 2       10.40              Clouds
# 3       10.27               Clear
# 4        4.18              Clouds
# 5       13.42               Clear
# 6        7.14              Clouds
# 7        7.38               Clear
# 8        9.22               Clear
# 9        1.41              Clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
